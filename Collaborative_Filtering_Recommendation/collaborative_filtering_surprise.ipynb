# %%
import numpy as np
import pandas as pd
from surprise import Reader, Dataset, SVD, evaluate

# %%
movie = pd.read_csv('movie.csv')
rating = pd.read_csv('rating.csv')

# %%
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rating.drop('Unnamed: 0', axis=1, inplace=True)
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
combined_data = pd.merge(rating, movie, on='movieId')
combined_data.head()
# Out:
#    userId  movieId  rating            timestamp           title  \
# 0       1        2     3.5  2005-04-02 23:53:47  Jumanji (1995)
# 1       5        2     3.0  1996-12-25 15:26:09  Jumanji (1995)
# 2      13        2     3.0  1996-11-27 08:19:02  Jumanji (1995)
# 3      29        2     3.0  1996-06-23 20:36:14  Jumanji (1995)
# 4      34        2     3.0  1996-10-28 13:29:44  Jumanji (1995)
#
#                        genres
# 0  Adventure|Children|Fantasy
# 1  Adventure|Children|Fantasy
# 2  Adventure|Children|Fantasy
# 3  Adventure|Children|Fantasy
# 4  Adventure|Children|Fantasy

# %% [markdown]
# ### What did user 1 like in the past?

# %%
user = combined_data[combined_data.userId == 1]
user_like = user[user.rating>=4.5].loc[:,['userId', 'movieId', 'title', 'rating']]
user_like
# Out:
#        userId  movieId                                              title  \
# 9407        1     1196  Star Wars: Episode V - The Empire Strikes Back...
# 9874        1     1198  Raiders of the Lost Ark (Indiana Jones and the...
# 22618       1     4993  Lord of the Rings: The Fellowship of the Ring,...
# 23353       1     5952      Lord of the Rings: The Two Towers, The (2002)
# 24476       1     7153  Lord of the Rings: The Return of the King, The...
# 25265       1     8507                                      Freaks (1932)
# 25276       1     8636                                Spider-Man 2 (2004)
#
#        rating
# 9407      4.5
# 9874      4.5
# 22618     5.0
# 23353     5.0
# 24476     5.0
# 25265     5.0
# 25276     4.5

# %% [markdown]
# ### Let's predict top 5 movies user 1 would love to watch:

# %%
reader = Reader()
svd = SVD()

data = Dataset.load_from_df(combined_data[['userId', 'movieId', 'rating']], reader)
trainset = data.build_full_trainset()
svd.fit(trainset)

user_would_like = user_like.copy()
user_would_like['estimate_score'] = user_would_like['movieId'].apply(lambda x: svd.predict(1, x).est)

#user_would_like = user_would_like.drop('movieId', axis = 1)

user_would_like = user_would_like.sort_values('estimate_score', ascending=False)
user_would_like.head()
# Out:
#        userId  movieId                                              title  \
# 24476       1     7153  Lord of the Rings: The Return of the King, The...
# 22618       1     4993  Lord of the Rings: The Fellowship of the Ring,...
# 23353       1     5952      Lord of the Rings: The Two Towers, The (2002)
# 9407        1     1196  Star Wars: Episode V - The Empire Strikes Back...
# 9874        1     1198  Raiders of the Lost Ark (Indiana Jones and the...
#
#        rating  estimate_score
# 24476     5.0        4.692548
# 22618     5.0        4.442688
# 23353     5.0        4.399500
# 9407      4.5        4.369927
# 9874      4.5        4.213067
